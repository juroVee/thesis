# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.lines as ml
from maux import *
from jedit import editor

#### vstupné údaje
def f(X): return 7 - X # ufunc verzia funkcie
X = np.linspace(-5, 10, 4*10+1) # výber hodnôt nezávislej premennej pre zaujímavú časť grafu
Y = f(X) # odpovedajúce hodnoty závislej premennej

#### obrázok s jedným diagramom
fig, ax = plt.subplots()
fig.set_size_inches(4,8) # veľkosť obrázka (východzia hodnota je 6x4)

### diagram

## inicializácia diagramu: vytvorí sa pravoúhla súradnicová sústava
init_subplot(ax)

## pomenovanie diagramu
ax.set_title(r"Graf a priebeh funkcie $y = 7 - x$")

## nastavenie rovnakej mierky pre obe osi
ax.set_aspect('equal')

## pravoúhla sieť
ax.grid()

## graf funkcie
ax.plot(X, Y)

### archivácia obrázka
#plt.savefig("<meno súboru>.png")

### samotné zobrazenie
plt.show()
#plt.close('all')
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
editor.run(fig=fig, ax=ax, f=f, X=[X])
# Out:
#             <style>
#             .output_wrapper button.btn.btn-default,
#             .output_wrapper .ui-dialog-titlebar {
#               display: none;
#             }
#             </style>
# VBox(children=(Tab(children=(GridspecLayout(children=(VBox(children=(Output(outputs=({'output_type': 'display_…
