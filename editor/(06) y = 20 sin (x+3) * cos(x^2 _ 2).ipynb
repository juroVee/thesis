# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from maux import *
from jedit import editor

#####
##### nakreslenie grafu funkcie
#####

#### vstupné údaje
def f(X): return 20 * np.sin(X + 3) * np.cos((X**2) / 2) # ufunc verzia funkcie
X = np.linspace(-5, 5, 10+1) # výber hodnôt nezávislej premennej pre zaujímavú časť grafu
Y = f(X) # odpovedajúce hodnoty závislej premennej

#### obrázok s jedným diagramom
fig, ax = plt.subplots()
fig.set_size_inches(7, 9) # veľkosť obrázka (východzia hodnota je 6x4)

### diagram
init_subplot(ax) # inicializácia diagramu: vytvorí sa pravoúhla súradnicová sústava
ax.set_title(r"Graf funkcie $y = 20 \: sin(x+3) \: cos(\frac{x^2}{2})$") # pomenovanie diagramu
ax.set_aspect('auto') # nastavenie rovnakej mierky pre obe osi
ax.grid() # pravoúhla sieť
ax.get_xticks()

## graf funkcie
ax.plot(X, Y)

### archivácia obrázka
#fig.savefig("<meno súboru>.png")

### samotné zobrazenie
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="699.6">

# %%
editor(figure=fig, axes=ax, function=f, intervals=[X])
# Out:
#             <style>
#             .output_wrapper button.btn.btn-default,
#             .output_wrapper .ui-dialog-titlebar,
#             .output_wrapper .mpl-message,
#             .output_wrapper .ui-icon {
#               display: none!important;
#             }
#             </style>
# VBox(children=(Tab(children=(GridspecLayout(children=(VBox(children=(Output(layout=Layout(overflow='hidden')),…
# [   -3.9633273     -3.06998012   -21.84955592    -1.77245385
#      0.14159265     0.14159265     0.14159265     1.77245385
#  20586.37151376     3.28318531     3.9633273 ]
# [-3.9633273  -3.06998012 -1.77245385  0.14159265  0.14159265  0.14159265
#   1.77245385  3.28318531  3.9633273 ]
# [-3.9633273  -3.06998012 -1.77245385  0.14159265  0.14159265  0.14159265
#   1.77245385  3.28318531  3.9633273 ]
# [   -3.9633273     -3.06998012   -21.84955592    -1.77245385
#      0.14159265     0.14159265     0.14159265     1.77245385
#  20586.37151376     3.28318531     3.9633273 ]
# [-3.9633273  -3.06998012 -1.77245385  0.14159265  0.14159265  0.14159265
#   1.77245385  3.28318531  3.9633273 ]
# [-3.9633273  -3.06998012 -1.77245385  0.14159265  0.14159265  0.14159265
#   1.77245385  3.28318531  3.9633273 ]
