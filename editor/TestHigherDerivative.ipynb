# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from maux import *
from jedit import editor

#### vstupné údaje
def f(X): return np.exp(X) + np.exp(-X) + 2 * np.cos(X)
X = np.linspace(-2, 2, 100+1)
Y = f(X)

fig, ax = plt.subplots()
fig.set_size_inches(8, 6)

init_subplot(ax)
ax.set_title(r"Graf funkcie $y = e^x + e^{-x} + 2cos(x)$")
ax.grid()

ax.plot(X, Y)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="799.7">

# %%
editor(figure=fig, axes=ax, function=f, intervals=[X])
# Out:
#             <style>
#             .output_wrapper button.btn.btn-default,
#             .output_wrapper .ui-dialog-titlebar,
#             .output_wrapper .mpl-message,
#             .output_wrapper .ui-icon {
#               display: none!important;
#             }
#             </style>
# VBox(children=(Tab(children=(GridspecLayout(children=(VBox(children=(Output(layout=Layout(overflow='hidden')),…
# Pracujem s 1. a 2. deriváciou...
#
# Nasiel som tychto kandidatov na extremy:
#
#              a        f1(a)        f2(a)
# 0 0.0000000000 0.0000000000 0.0000000000
#
# Nenasiel som nenulove derivacie 2. stupna!
#
# --------------------------------------------------
#
# Pracujem s 1. a 3. deriváciou...
#
# Nasiel som tychto kandidatov na extremy:
#
#              a        f1(a)        f3(a)
# 0 0.0000000000 0.0000000000 0.0000000000
#
# Nenasiel som nenulove derivacie 3. stupna!
#
# --------------------------------------------------
#
# Pracujem s 1. a 4. deriváciou...
#
# Nasiel som tychto kandidatov na extremy:
#
#              a        f1(a)        f4(a)
# 0 0.0000000000 0.0000000000 3.9999999995
#
# Vsetky 4. derivacie su nenulove a n = 4 je parne -> MAM VYSLEDOK
#
# minimá: [0.] maximá: []
