# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.lines as ml
from maux import *
from jedit import editor

#####
##### nakreslenie grafu funkcie
#####

#### vstupné údaje
def f(X): return (X ** 2 / 2) + X - 2 # ufunc verzia funkcie
X = np.linspace(-2, 3, 5*10+1) # výber hodnôt nezávislej premennej pre zaujímavú časť grafu
Y = f(X) # odpovedajúce hodnoty závislej premennej

def d(X): return X + 1
def d2(X): return 1

#### obrázok s jedným diagramom
fig, ax = plt.subplots()
fig.set_size_inches(5, 8) # veľkosť obrázka (východzia hodnota je 6x4)

### diagram
init_subplot(ax) # inicializácia diagramu: vytvorí sa pravoúhla súradnicová sústava
ax.set_title(r"Graf funkcie $y = \dfrac{x^2}{2}+x-2$") # pomenovanie diagramu
ax.set_aspect('equal') # nastavenie rovnakej mierky pre obe osi
#ax.grid() # pravoúhla sieť

## graf funkcie
ax.plot(X, Y)

### archivácia obrázka
#plt.savefig("<meno súboru>.png")

### samotné zobrazenie
plt.show()
#plt.close('all')
# Out:
# <img src="data:image/png;base64,..." width="499.95">

# %%
editor(figure=fig, axes=ax, function=f, intervals=[X])
# Out:
#             <style>
#             .output_wrapper button.btn.btn-default,
#             .output_wrapper .ui-dialog-titlebar,
#             .output_wrapper .mpl-message {
#               display: none;
#             }
#             </style>
# VBox(children=(Tab(children=(GridspecLayout(children=(VBox(children=(Output(layout=Layout(overflow='hidden')),…
