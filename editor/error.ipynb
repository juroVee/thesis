# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import ipywidgets as widgets
from maux import *
from jedit import editor

# %%
def f(X): return X ** 3 + 3 * X ** 2 - 9 * X - 10
X = np.linspace(-5, 3)
fig, ax = plt.subplots()
init_subplot(ax)
ax.grid()
ax.plot(X, f(X))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.65">

# %% [markdown]
# Toto volanie editora sposobi, ze nasledujuci interaktivny priklad nefunguje spravne.

# %%
editor(fig=fig, ax=ax, f=f, X=[X])
# Out:
#             <style>
#             .output_wrapper button.btn.btn-default,
#             .output_wrapper .ui-dialog-titlebar,
#             .output_wrapper .mpl-message {
#               display: none;
#             }
#             </style>
# VBox(children=(Tab(children=(GridspecLayout(children=(VBox(children=(Output(),), layout=Layout(grid_area='widg…

# %%
#####
##### grafy parametrického systému funkcií (interaktívna verzia)
#####

#### vstupné údaje
def f(X, a): return a * X
X = np.linspace(-3, 3, 6*10+1)

#### obrázok s jedným diagramom
fig, ax = plt.subplots()
fig.set_size_inches(6, 6)

### diagram
init_subplot(ax)
ax.grid()

## graf funkcie y = ax
def plot_graph(a):
    if ax.lines:
        ax.lines[0].set_ydata(f(X, a))
    else:
        ax.plot(X, f(X, a))

widgets.interact(plot_graph,
                 a=widgets.FloatSlider(min=-2, max=2, value=1, step=0.1),
                )

### samotné zobrazenie
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="599.5">
# interactive(children=(FloatSlider(value=1.0, description='a', max=2.0, min=-2.0), Output()), _dom_classes=('wi…
